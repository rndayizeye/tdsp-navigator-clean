# %% [markdown]
# <a href="https://colab.research.google.com/github/rndayizeye/tdsp-navigator-clean/blob/main/Remy_Ndayizeye_Copy_NAVIGATOR_Transportation_Data_Science_Project_(TDSP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🛺 **Welcome to the <font color='green'>** **Navigator Transportation Data Science Project! 🛺**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='green'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Navigator TDSP has eight Milestones, including guided transportation research. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# The Navigator TDSP was designed with intermediate learners in mind. We highly recommend you begin with the Explorer TDSP before moving on to the Navigator TDSP. However, completion of the Explorer TDSP is not required to participate in the Navigator TDSP.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!
#
# Any questions, please email er3101@columbia.edu.

# %% [markdown]
# ## <font color='green'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Navigator TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='green'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='green'>**A Deeper Dive into Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to practice with Python and data analysis, we recommend you begin with the Explorer TDSP. For those looking to dive deeper into Python, including advanced topics, here are some valuable resources:
# - [Jobtensor Python Introduction](https://jobtensor.com/Tutorial/Python/en/Introduction) - Provides an overview of Python, including introductory to advanced concepts and tutorials.
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# ## <font color='green'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# To install a library, we'll use the following format:
# ```python
#  import <library> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import warnings
from google.colab import drive
import pathlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# These are the libraries that will help us throughout this project.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **Step 2:**
#
# Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA). Fill in the blanks below.

# %%
#TODO: Mount your Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
NOTEBOOK_PATH = pathlib.Path().resolve()
DATA_DIRECTORY = NOTEBOOK_PATH/"drive/MyDrive/TDSP"
DATA_DIRECTORY
# Out:
# PosixPath('/content/drive/MyDrive/TDSP')

# %%
# TODO: Read the data using pandas read_csv function and setting the data type to pyarrow
data = pd.read_csv("/content/drive/MyDrive/TDSP/Motor_Vehicle_Collisions_-_Crashes_20241228.csv")
# Out:
# /tmp/ipykernel_6028/188341436.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/TDSP/Motor_Vehicle_Collisions_-_Crashes_20241228.csv")

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='green'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to explore and better understand the dataset using charts and graphs.
#
# Before we begin, it is important that we understand the core concept of data science ethics. To best prepare yourself, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [Everyday Ethics with IBM](https://www.ibm.com/watson/assets/duo/pdf/everydayethics.pdf)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)

# %% [markdown]
# **Step 1:** Begin by computing the summary statistics for injuries and fatalities, respectively, by leveraging the describe function. Need a refresher on summary statistics? [Check out this resource!](https://goodboychan.github.io/python/datacamp/statistics/2020/08/26/01-Summary-Statistics-with-Python.html)

# %%
#TODO: Leverage the describe() function to assess the summary statistics for injuries and fatalities
injury_stats = data['NUMBER OF PERSONS INJURED'].describe()
fatality_stats = data['NUMBER OF PERSONS KILLED'].describe()
injury_stats, fatality_stats
# Out:
# (count    2.144973e+06
#  mean     3.192497e-01
#  std      7.077703e-01
#  min      0.000000e+00
#  25%      0.000000e+00
#  50%      0.000000e+00
#  75%      0.000000e+00
#  max      4.300000e+01
#  Name: NUMBER OF PERSONS INJURED, dtype: float64,
#  count    2.144960e+06
#  mean     1.540821e-03
#  std      4.143115e-02
#  min      0.000000e+00
#  25%      0.000000e+00
#  50%      0.000000e+00
#  75%      0.000000e+00
#  max      8.000000e+00
#  Name: NUMBER OF PERSONS KILLED, dtype: float64)

# %% [markdown]
# Review the chart you've created above. You can see that most crashes result in no injuries or fatalities, as evidenced by the median and 75th percentile values being 0. However, there are some severe crashes with a higher number of injuries or fatalities.

# %% [markdown]
# **TO DO:** Are there any other insights you can pull from the above chart?
# > *  The deadliest crashes took 8 lives while to most injuries from a single crash was 43. While these are extreme cases they demostrate why preventing every sign crash matter.

# %% [markdown]
# **Step 2:** Now, let's create a bar chart to determine which vehicle types were involved in the most **injuries *and* deaths**. In order to create a bar chart that displays two variables at very different scales, we will need to create a second axis. To learn more about this method and its drawbacks, [review this resource](https://python-graph-gallery.com/line-chart-dual-y-axis-with-matplotlib/). Then, fill in the code below.

# %%
# TODO: Calculate top vehicles for injuries
top_vehicles_injuries = data.groupby('VEHICLE TYPE CODE 1')["NUMBER OF PERSONS INJURED"].sum().sort_values(ascending=False).head(10)
# TODO: Calculate top vehicles for deaths
top_vehicles_deaths = data.groupby("VEHICLE TYPE CODE 1")['NUMBER OF PERSONS KILLED'].sum().sort_values(ascending=False).head(10)

# TODO: Combine the data into a DataFrame
combined_data = pd.DataFrame({'Injuries': top_vehicles_injuries, 'Deaths': top_vehicles_deaths})

# Set the width of the bars
bar_width = 0.35

# Plotting the combined bar chart with bars next to each other
fig, ax1 = plt.subplots(figsize=(12, 7))

# Generate a list of indices for the x-axis
indices = np.arange(len(combined_data))

# Plotting the bars for injuries
ax1.bar(indices - bar_width/2, combined_data['Injuries'], bar_width, color='blue', label='Injuries')

# TODO: Create a secondary y-axis for deaths
ax2 = ax1.twinx() # Create a twin Axes sharing the xaxis

# Plotting the bars for deaths next to injuries
ax2.bar(indices + bar_width/2, combined_data['Deaths'], bar_width, color='orange', label='Deaths')

# Adding labels and title
ax1.set_title('Top 10 Vehicles in Injuries and Deaths', fontsize=16)
ax1.set_xlabel('Vehicle Type', fontsize=14)
ax1.set_ylabel('Number of Injuries', fontsize=14)
# TODO: Set the label for the secondary y-axis
ax2.set_ylabel('Number of Injuries', fontsize=14)
ax1.set_xticks(indices)
ax1.set_xticklabels(combined_data.index, rotation=45, ha='right')

# Adding legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Adjusting layout and displaying the combined chart
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. Notice that the x-axis displays repetitive variables, such as Taxi and TAXI.
#
# Create a new bar chart below by converting all variables to UPPER CASE, and combining any repetitive variables.

# %%
# TODO: Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# TODO: Convert all variables in a specific column to upper case
data['VEHICLE TYPE CODE 1'] = data['VEHICLE TYPE CODE 1'].str.upper()

# Combine any repetitive variables
vehicle_types_to_combine = ['STATION WAGON/SPORT UTILITY VEHICLE', 'SPORT UTILITY / STATION WAGON']
# TODO: Replace specified values with a common label in a column
data['VEHICLE TYPE CODE 1'] = data['VEHICLE TYPE CODE 1'].replace(vehicle_types_to_combine, 'SUV/STATION WAGON')
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Re-run code from above
top_vehicles_injuries = data.groupby('VEHICLE TYPE CODE 1')['NUMBER OF PERSONS INJURED'].sum().sort_values(ascending=False).head(10)
top_vehicles_deaths = data.groupby('VEHICLE TYPE CODE 1')['NUMBER OF PERSONS KILLED'].sum().sort_values(ascending=False).head(10)
combined_data = pd.DataFrame({'Injuries': top_vehicles_injuries, 'Deaths': top_vehicles_deaths})
bar_width = 0.35
fig, ax1 = plt.subplots(figsize=(12, 7))
indices = np.arange(len(combined_data))
ax1.bar(indices - bar_width/2, combined_data['Injuries'], bar_width, color='blue', label='Injuries')
ax2 = ax1.twinx()
ax2.bar(indices + bar_width/2, combined_data['Deaths'], bar_width, color='orange', label='Deaths')
ax1.set_title('Top 10 Vehicles in Injuries and Deaths', fontsize=16)
ax1.set_xlabel('Vehicle Type', fontsize=14)
ax1.set_ylabel('Number of Injuries', fontsize=14)
ax2.set_ylabel('Number of Deaths', fontsize=14)
ax1.set_xticks(indices)
ax1.set_xticklabels(combined_data.index, rotation=45, ha='right')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were **most** involved in crashes that resulted in **injuries?**
#
# > *  SEDAN
# > *  SUV/STATION WAGON
# > *  PASSENGER VEHICLE

# %% [markdown]
# **TO DO:** Review the top 3 vehicles that were **most** involved in crashes that resulted in **deaths.** Do these vehicles differ from those that were most involved in **injuries?**
#
# > *   The analysis reveals a consistent trend: the vehicle types most frequently involved in injury-causing crashes—Sedans and SUVs—are identical to those involved in fatal collisions.

# %% [markdown]
# **TO DO:** Why do you think those vehicles are most involved in injury-causing and death-causing crashes?
#
# > *  Sedans are the most common vehicle types on US roads. Their small size makes them vurnarable during crashes with bigger vehicle such as SUVs.
# > * SUVs a poor front visibility and blind spots leading to collision with smaller veicles and pedestrians. Additionally, their higher center of gravity making them to vurnalable to crashes when sudden lanes changes are involved.

# %% [markdown]
# **TO DO:** Are there any recommendations you would make to the Dept. of Transportation based on the data above? Feel free to be creative.
#
# > *  Proposed Intervention: Implement stricter federal safety standards for SUV front-end geometry to improve visibility and reduce impact severity for pedestrians.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='green'> **Milestone #3 - Advanced Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the foundations, including Trends, Seasonality, and Residual Components.
#
# If needed, review one or more of the following resources to refresh your knowledge.
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **Step 2:** Begin by creating a chart that displays the average number of crashes per day of the week, including Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, & Sunday.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset


file_path = "/content/drive/MyDrive/TDSP/Motor_Vehicle_Collisions_-_Crashes_20241228.csv"
data = pd.read_csv(file_path, dtype_backend= 'pyarrow')

# TODO: Convert 'CRASH DATE' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Day of the Week Analysis
# TODO: Add a new column for the day of the week from 'CRASH DATE'
data['Day of Week'] = data['CRASH DATE'].dt.day_name()
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Group by 'Day of Week' and calculate the average number of crashes per day
average_crashes_per_weekday = data.groupby('Day of Week').size() / data['Day of Week'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(10, 6))
# TODO: Plot a bar chart with seaborn
sns.barplot(x=average_crashes_per_weekday.index, y=average_crashes_per_weekday.values, order=day_order)
plt.title('Average Number of crashes per Weekday')
plt.xlabel('Day of the Week')
plt.ylabel('Average Number of crashes')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_6028/1110702677.py:9: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, dtype_backend= 'pyarrow')

# %% [markdown]
# **TO DO:** Which day of the week sees the most crashes? Why do you think so?
#
# > *  Most crashes occur on Fridays. Driver fatigue after a long week of work and increase in traffice volume may be a factor
#
# **TO DO:** Which day of the week sees the least crashes? Why do you think so?
#
# > *  Sunday has the least number of crashes. Most people stay off roads and are rested.

# %% [markdown]
# **Step 3:** [Stationarity Check](https://otexts.com/fpp2/stationarity.html)! Time series data should be stationary for most forecasting methods to work effectively. Let's check if the series is stationary and apply transformations if necessary, leveraging the [Augmented Dickey-Fuller test](https://www.machinelearningplus.com/time-series/augmented-dickey-fuller-test/).

# %%
from statsmodels.tsa.stattools import adfuller

# TODO: Count the number of crashes per day
daily_crashes = data.groupby('CRASH DATE').size()

# Perform Augmented Dickey-Fuller test
# TODO: Use adfuller to test if daily crashes are stationary
adf_test = adfuller(daily_crashes)

# Display the ADF test results
# TODO: Create a pandas Series to nicely display test results
adf_output = pd.Series(adf_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key, value in adf_test[4].items():
    adf_output[f'Critical Value ({key})'] = value

# TODO: Print the ADF test output
print(adf_output)
# Out:
# Test Statistic                   -1.318930
# p-value                           0.620468
# #Lags Used                       29.000000
# Number of Observations Used    4530.000000
# Critical Value (1%)              -3.431794
# Critical Value (5%)              -2.862178
# Critical Value (10%)             -2.567110
# dtype: float64

# %% [markdown]
# [Review this resource for a refresher on test statistics and P-values](https://www.investopedia.com/terms/p/p-value.asp). Then, review the results of the Augmented Dickey-Fuller (ADF) test below:
#
# Test Statistic: -1.395
#
# p-value: 0.585
#
# The p-value is greater than the common significance level (0.05), indicating that we *fail to reject the null hypothesis*. Therefore, we can infer that the time series is *not stationary*.
# We typically apply differencing to make the series stationary. After differencing, we can recheck for stationarity and then proceed with selecting and fitting an appropriate forecasting model.

# %% [markdown]
# **Step 4:** In order to make the series stationary, let's apply differencing. [Review this resource to learn more about Time Series Differencing](https://www.influxdata.com/blog/time-series-differencing-complete-guide-influxdb/). **Then, perform the ADF test on the differenced series, and display the results.**

# %%
# TODO: Apply first differencing
daily_crashes_diff = daily_crashes.diff().dropna()

# Perform Augmented Dickey-Fuller test on the differenced series
# TODO: Use adfuller to test if the differenced series is stationary
adf_test_diff = adfuller(daily_crashes_diff)

# Display the ADF test results for the differenced series
# TODO: Create a pandas Series to nicely display test results
adf_output_diff = pd.Series(adf_test_diff[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key, value in adf_test_diff[4].items():
    adf_output_diff[f'Critical Value ({key})'] = value

# TODO: Print the ADF test output for the differenced series
print(adf_output_diff)
# Out:
# Test Statistic                -1.708627e+01
# p-value                        7.645507e-30
# #Lags Used                     3.200000e+01
# Number of Observations Used    4.526000e+03
# Critical Value (1%)           -3.431796e+00
# Critical Value (5%)           -2.862179e+00
# Critical Value (10%)          -2.567110e+00
# dtype: float64

# %% [markdown]
# The results of the Augmented Dickey-Fuller test on the differenced series are:
#
# Test Statistic: Approximately -18.19
#
# p-value: Approximately 0
#
# The p-value is significantly lower than common significance level (0.05).

# %% [markdown]
# **TO DO:** Since the p-value is lower than the common significance level (0.05), do we accept or reject the null hypothesis?
#
# > *  We reject the null

# %% [markdown]
# **TO DO:** Based on your response, is the series stationary or not stationary?
#
# > *  Stationary

# %% [markdown]
# **Step 5:** Create an ARIMA Model for Time Series forecasting.
#
# An ARIMA model, also known as an AutoRegressive Integrated Moving Average model, is a statistical method that allows you to analyze and forecast time series data.
#
# [Review this resource](https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/) to learn more about the ARIMA model, how to fit the model, and how to configure the model.
#
# Fill in the model below.

# %%
#!pip install prophet

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Convert the 'CRASH DATE' column to datetime format. Replace 'CRASH DATE' if your date column has a different name.
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# TODO: Group data by 'CRASH DATE' and count the crashes. Assign this to a new DataFrame called 'daily_crashes'.
daily_crashes = data.groupby('CRASH DATE').size().reset_index(name='crash_count')

# TODO: Rename the columns of 'crash_count' to 'y' for Prophet compatibility.
daily_crashes.rename(columns={'CRASH DATE': 'ds', 'crash_count': 'y'}, inplace=True)

model = Prophet()
model.fit(daily_crashes)

# TODO: Create a future dataframe for forecasting the next 30 days and assign it to a variable called 'future'.
future = model.make_future_dataframe(periods = 30)

# TODO: Use the model to make predictions on the 'future' DataFrame and store the result in a variable called 'forecast'.
forecast = model.predict(future)

# TODO: Plot the forecasted data using the Prophet's built-in plot function.
fig = model.plot(forecast)
plt.title('30-Day Forecast of Daily Motor Vehicle Collisions')
plt.xlabel('Date')
plt.ylabel('Number of Crashes')
plt.show()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ###Understanding the plot
#
# Black Dots: Each black dot represents the actual number of crashes recorded on a given day.
#
# Dark Blue Line: The dark blue line shows the predicted median number of crashes per day. This is the model's best guess for the central tendency of crashes for future dates.
#
# Light Blue Shaded Area: The light blue shaded area around the dark blue line represents the uncertainty interval of the forecast. The wider this area, the higher the uncertainty. It's usually narrow close to the last observed data point and widens as you move further into the future, indicating increasing uncertainty in the forecast.
#
# Forecast Period: The forecast itself happens after the last available actual data point. If the graph is not clearly demarcated, you would look for the point where there are no more black dots, and the blue line continues. This continuation beyond the last black dot into the light blue area is the forecasted period.

# %% [markdown]
# The graph represents a time series forecasting mondel.
#
# * The shaded area represents the uncertainty intervals around the forecast.
# * The forecast seems to continue the recent downward trend in the number of crashes.
# * The uncertainty interval grows as the forecast extends further into the future, which is common in time series forecasting due to the compounding of errors.

# %% [markdown]
# **TO DO:** What insights have you gained from the above ARIMA model? Based on your forecast, do you have any recommendations for the Dept. of Transportation?
#
# > *  Daily crashes has been going trending up until late 2019. The big drop early 2020 correspond to COVID-19 Global Pandemic with fewer individuals traveling due to remote work policies and moving away from cities. However, fewer vehicles on the road is an opportunity for excessive speed that could result in higher fatalities. The Dept. of Transportation should focus on speed control targeting high risk areas and time based on data by increasing posted speed limit, interactive signs displaying speed.

# %%
daily_crashes['ds'].max()
# Out:
# Timestamp('2024-12-24 00:00:00')

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='green'>**Milestone #4 - Spatio-Temporal Analysis**</font>
# GOAL: The main goal of this milestone is to explore data that is collected across both space (spatio) and time (temporal), and to get comfortable with spatio-temporal visualizations.

# %% [markdown]
# **Step 1:** [Review this resource](https://www.heavy.ai/technical-glossary/spatial-temporal) to read more about Spatio-Temporal Data Analysis. Then, let's try to create visualizations that demonstrate the spatio-temporal [correlation](https://www.jmp.com/en_us/statistics-knowledge-portal/what-is-correlation.html) of collisions. Begin by plotting the yearly collision frequencies by borough to see if there are any patterns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'CRASH DATE' to datetime and extract year and month for easier analysis
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['YEAR'] = data['CRASH DATE'].dt.year
data['MONTH'] = data['CRASH DATE'].dt.month

# Analyzing collision frequencies over time in different boroughs
# Grouping data by Year and Borough
borough_yearly = data.groupby(['YEAR', 'BOROUGH']).size().unstack(fill_value=0)

# Plotting the data
plt.figure(figsize=(15, 7))
# TODO: Use seaborn to create a line plot
sns.lineplot(data=borough_yearly)
plt.title('Yearly Collision Frequencies by Borough')
plt.ylabel('Number of Collisions')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.legend(title='Borough', loc='upper left')
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Step 2:** Now, let's analyze the distribution of crashes by month and borough. To do this, we will create a heatmap. To review some of the different types of heatmaps you can create in Python, [use this resource](https://python-graph-gallery.com/90-heatmaps-with-various-input-format/)! Then, fill in the code below.

# %%
# Analyzing specific times or locations with unusually high numbers of crashes
# For this, we will use a heatmap to visualize the distribution of crashes by month and borough

# Grouping data by Month and Borough
borough_monthly = data.groupby(['MONTH', 'BOROUGH']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 8))
# TODO: Create a heatmap to visualize the frequencies
sns.heatmap(borough_monthly, cmap="YlGnBu", annot=True, fmt='d')
plt.title('Monthly Collision Frequencies by Borough')
plt.ylabel('Month')
plt.xlabel('Borough')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# **TO DO:** Review the two visualizations you have just created directly above. List three to five insights you've gained from these visualizations. Are there recommendations you would make to the Dept. of Transportation based on these insights?
#
# > * Most collisions since 2014 occur in Brooklyn (1st) and Queens (2nd)
# > *  Manhattan saw a steep decline in number of collisions since 2015
# > *  Staten Island recorded the lowest absolute collision frequency, likely attributable to its significantly lower population density and different land-use patterns compared to boroughs like Brooklyn.
# > *  Vision Zero initiative is a flagship project that led to safer roads NYC with the highest impact in Manahattan. Existing infrastrure such as wider roads allowed creation of dedicated bike lanes and a more pedestrian centric design
# > *  The Dept of Transportation should imprement the remiaging implementation of Vision Zero to adjust for local borgough context.

# %% [markdown]
# **Step 3:** Create a correlation matrix for the number of collisions in different boroughs across different years. Need a refresher on correlation? Watch the [NSDC Descriptive Statistics Flashcard Video Series to learn more](https://youtube.com/playlist?list=PLNs9ZO9jGtUBQfxw7YAmtZJPRiEpnwaNc&feature=shared)!

# %%
# Creating a correlation matrix for the number of collisions in different boroughs across different years
correlation_matrix = borough_yearly.corr()

plt.figure(figsize=(10, 8))
# TODO: Plot the correlation matrix using a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt='.2f')
plt.title('Correlation Matrix of Collision Frequencies Across Boroughs')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# The correlation matrix provides a visual and numerical representation of the relationships between collision frequencies across different boroughs over the years. Values close to 1 indicate a strong positive correlation, meaning that as collisions increase in one borough, they tend to also increase in the other. Values close to -1 indicate a strong negative correlation, and values around 0 suggest no significant correlation.

# %% [markdown]
# **TO DO:** Based on the information above, which boroughs are the most and least correlated?
# > *  Most: QUEENS and BROOKLYN
# > *  Least: BRONX and STATEN ISLAND

# %% [markdown]
# **TO DO:** Why do you think certain boroughs are more correlated than others?
# > * Certain areas are more correlated than other because they share underlying conditions that lead to more car crashes. And the oppositite is true.
# Bronx and Staten Island differ in social economic status, with the median income in Staten Island twice that of the Bronx. Even though Staten Island has one more vehicle per household than the Bronx, the Bronx is home to one million more people with the density four time more than State Island. a density four time more than State Island. Conversely, Brooklyn and Queens are number of crashes are correlated due to their geographic proximity, socio-ecomonic and demographic similarities. Both boroughs are

# %% [markdown]
# ##<font color='green'>**Milestone #5 - Location Inequality**</font>
# GOAL: The main goal of this milestone is to think about the implications of this data. You will be given an open-ended question that you may research however you like, as long as it's approachable and appropriate. We've included an example for research inspiration below!

# %% [markdown]
# **Step 1:** Analyze the data to research the following question:
#
# Is there any location inequality in terms of automobile crash rates, pedestrian fatality and injury? What is the relationship between pedestrian fatalities and neighborhood poverty of residence?

# %% [markdown]
# **Example:**
#
# Here is an example answer to inspire you, emphasizing the measurement of the "inequality" factor in crash rates: [detecting the change of point](https://pro.arcgis.com/en/pro-app/latest/tool-reference/space-time-pattern-mining/how-change-point-detection-works.htm). One can further investigate whether distinct locations exhibit similar points of change.

# %%
# install and import the package for the change-of-point detection
# !pip install ruptures
import ruptures as rpt

# aggrate the total crash by dates
Counts=data["CRASH DATE"].value_counts()
Counts.index = pd.to_datetime(Counts.index)
Counts.sort_index(inplace=True)
Counts_2022 = Counts.loc['2022-01-01':'2022-12-31'].rolling(7).mean().dropna()


# implement the algorithm
model = "l2"
algo = rpt.Binseg(model=model).fit(Counts_2022.to_numpy())
my_bkps = algo.predict(n_bkps=10)
# show results
fig, ax = plt.subplots(figsize=(18,8))
ax = plt.gca()
ax.plot_date(Counts_2022.index, Counts_2022.to_numpy(), linestyle='solid')
#rpt.show.display(Counts_2022.to_numpy(), my_bkps, figsize=(10, 6))
plt.ylim([0.9*Counts_2022.min(), 1.1*Counts_2022.max()])

# changing point
my_bkps.pop()
for ix in my_bkps:
    plt.plot([Counts_2022.index[ix], Counts_2022.index[ix]], [0,1000], '--k')

plt.title('Change Point Detection: Binary Segmentation Search Method - Year 2022')
plt.ylabel("Total Crash Count in NYC")
plt.xlabel("Date")
print(my_bkps)
# Out:
# ...
# /tmp/ipykernel_6028/13605152.py:19: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   ax.plot_date(Counts_2022.index, Counts_2022.to_numpy(), linestyle='solid')
# [25, 45, 55, 60, 105, 110, 130, 180, 305, 355]

# %%
# clean columns and lower case
data.columns = data.columns.str.lower()
data.columns = data.columns.str.strip()
data.columns = data.columns.str.replace(' ', '_')

# %%
missing_location = data[data['zip_code'].isna() & data['location'].isna()]
missing_location_percent =(data[data['zip_code'].isna() & data['location'].isna()]).shape[0]/data.shape[0]*100
print(f"Percentage of crashes missing location data: {missing_location_percent:.2f}%")
# Out:
# Percentage of crashes missing location data: 9.42%

# %% [markdown]
# ### Downloading census tracts in NYC
# Using the pygris package, I downloaded the census tracts in for the five borough in New York City then removed water for clarity.

# %%
import importlib # Import importlib for dynamic imports

packages_dict = {
    "pygris": "pg",
    "mapclassify": "mapclassify",
    "geopandas":"gpd",# Key must be a string
}

for package, short_hand in packages_dict.items(): # .items() is a method
  try:
    # Use importlib to dynamically import the module and assign it to the alias
    globals()[short_hand] = importlib.import_module(package)
  except ImportError:
    print(f"Installing {package}...") # Added a print statement for clarity during installation
    # !pip install {package}
    # After installation, retry the import
    globals()[short_hand] = importlib.import_module(package)

# %%
nyc_county_fips = ['005', '047', '061', '081', '085']
nyc_fips_to_name_map = {
    '005': 'Bronx',
    '047': 'Brooklyn',
    '061': 'Manhattan',
    '081': 'Queens',
    '085': 'Staten Island'
}

nyc_tracts = pg.tracts(state=36, county=nyc_county_fips, year=2024, cb=True, cache=True)
#adding borough name
nyc_tracts['borough'] = nyc_tracts['COUNTYFP'].map(nyc_fips_to_name_map)
#removing water
nyc_tracts_no_water = erase_water(nyc_tracts)

#project the coordinate
nyc_tracts_no_water = nyc_tracts_no_water.crs = "EPSG:4326"

# %%
# clean columns and lower case
nyc_tracts_2024.columns = nyc_tracts_2024.columns.str.lower()
nyc_tracts_2024.columns = nyc_tracts_2024.columns.str.strip()
nyc_tracts_2024.columns = nyc_tracts_2024.columns.str.replace(' ', '_')

# %%
#creating a geodataframe from data
nyc_crashes = gpd.GeoDataFrame(
    data = data,
    geometry = gpd.points_from_xy(data['longitude'], data['latitude'], crs="EPSG:4326"),
    crs = "EPSG:4326"
)

# %%
#spatial join the geodataframe of crashes location to their respective cencus tracts
#https://geopandas.org/en/stable/docs/user_guide/mergingdata.html
assert nyc_crashes.crs == nyc_tracts_2024.crs, "CRS should match!"
# Filter out records without coordinates to avoid spatial join errors
nyc_crashes_clean = nyc_crashes.dropna(subset=['latitude', 'longitude'])

nyc_crashes_tracts_joined = gpd.sjoin(nyc_crashes,nyc_tracts_2024,
                                          how = 'left',
                                          predicate = 'within',
                                          lsuffix="crash", rsuffix='tract')

# Handling points that don't fall into any polygon
# If a point doesn't fall into any polygon, the columns from the right GeoDataFrame
# will be filled with NaN values.

collisions_not_in_tract = nyc_crashes_tracts_joined[nyc_crashes_tracts_joined['tractce'].isna()]
print(f"Number of collisions not in any tract: {collisions_not_in_tract.shape[0]}")
# Out:
# Number of collisions not in any tract: 253989

# %%
# removing collisions_not_in_tract
nyc_crashes_in_tracts = nyc_crashes_tracts_joined[~nyc_crashes_tracts_joined['tractce'].isna()]

# %%
# clean columns and lower case
nyc_crashes_in_tracts.columns = nyc_crashes_in_tracts.columns.str.lower()
nyc_crashes_in_tracts.columns = nyc_crashes_in_tracts.columns.str.strip()
nyc_crashes_in_tracts.columns = nyc_crashes_in_tracts.columns.str.replace(' ', '_')

# %%
# creating a new aggrated dataframe to calculate indicator by zipcode and borough
columns= [
    'collision_id',
  'number_of_persons_injured',
 'number_of_persons_killed',
 'number_of_pedestrians_injured',
 'number_of_pedestrians_killed',
 'number_of_cyclist_injured',
 'number_of_cyclist_killed',
 'number_of_motorist_injured',
 'number_of_motorist_killed',
    'tractce'#,'crash_date'
]
aggregated_df = nyc_crashes_in_tracts[columns].groupby(['tractce']).agg(
    total_crashes=('collision_id', 'count'),
    total_persons_injured=('number_of_persons_injured', 'sum'),
    total_persons_killed =('number_of_persons_killed', 'sum'),
 total_pedestrians_injured = ('number_of_pedestrians_injured', 'sum'),
 total_pedestrians_killed =('number_of_pedestrians_killed','sum'),
 total_cyclist_injured= ('number_of_cyclist_injured','sum'),
 total_cyclist_killed = ('number_of_cyclist_killed','sum'),
 total_motorist_injured= ('number_of_motorist_injured','sum'),
 total_motorist_killed = ('number_of_motorist_killed','sum')
).reset_index()

#fill na with zero
aggregated_df.fillna(0, inplace=True)

# %% [markdown]
# ###Poverty by NY Census Tracts

# %%
#adding poverty by census tracts in NewYork
import requests
import pandas as pd
get_variables_acs5_2023 = ["NAME","GEO_ID","B01003_001E","B17001_001E","B17001_002E"]

#B01003_001E total population estimate
#"B17001_001E": "total_pop_poverty_status",
 #   "B17001_002E": "pop_below_poverty_level",


api_key= "636672d77da50ced5fa354e765cbbf7d050b6a97"
#setting the
base_url = "http://api.census.gov/data/2023/acs/acs5" #adjust year as needed.
geography = "tract"


# 3. Construct the API URL


predicates = {}
predicates["get"] = ",".join(get_variables_acs5_2023)
predicates["for"] = f"{geography}:*"
predicates["in"] = "state:36"
predicates["key"] = "636672d77da50ced5fa354e765cbbf7d050b6a97"


#request data
try:
    response = requests.get(base_url, params=predicates)
    response.raise_for_status()
    data_metro = response.json()
except requests.exceptions.RequestException as e:
    print(f"Error during API request: {e}")


poverty_2023 = pd.DataFrame(columns= response.json()[0], data= response.json()[1:])

print(poverty_2023.head())

# 6. Clean and prepare data
poverty_2023['GEO_ID'] = poverty_2023['GEO_ID'].str.split("US").str[1]
poverty_2023.rename(columns={"GEO_ID": "GEOID",
                             "B17001_001E": "total_pop_poverty_status",
                             "B17001_002E": "pop_below_poverty_level",
                             "NAME":"census tract",
                             "B01003_001E":"pop_est",
                             }, inplace=True)

# 7. Convert numeric columns
numeric_columns = ["total_pop_poverty_status","pop_below_poverty_level","pop_est"]
for col in numeric_columns:
    poverty_2023[col] = pd.to_numeric(poverty_2023[col], errors='coerce')

# 8. Print the first few rows
print(poverty_2023.head())

# 9. calcute poverty rate
poverty_2023['poverty_rate'] = (poverty_2023['pop_below_poverty_level'] / poverty_2023['total_pop_poverty_status']*100).round(2)
poverty_2023.head()


#save the date to google drive


poverty_2023.to_csv("/content/drive/MyDrive/Data Analysis Practice Projects/datasets/poverty_data_by_zipcode.csv", index=False)
# Out:
#                                          NAME                GEO_ID  \
# 0     Census Tract 1; Albany County; New York  1400000US36001000100
# 1  Census Tract 2.01; Albany County; New York  1400000US36001000201
# 2  Census Tract 2.02; Albany County; New York  1400000US36001000202
# 3  Census Tract 3.01; Albany County; New York  1400000US36001000301
# 4  Census Tract 3.02; Albany County; New York  1400000US36001000302
#
#   B01003_001E B17001_001E B17001_002E state county   tract
# 0        2156        2150         510    36    001  000100
# 1        2519        2519         805    36    001  000201
# 2        2436        2434         597    36    001  000202
# 3        2378        2378         667    36    001  000301
# 4        3273        3214         661    36    001  000302
#                                  census tract        GEOID  pop_est  \
# 0     Census Tract 1; Albany County; New York  36001000100     2156
# ...

# %%
import geopandas as gpd
import folium

boroughs_boundaries = gpd.read_file("/content/drive/MyDrive/TDSP/nyc_buroughs_boundaries.gpkg")




#creating a id column as str
aggregated_df['id'] = aggregated_df.index.astype(str)

#merging with nyc_zipcode_geocoded to create a gdf
aggregated_gdf = nyc_tracts_2024.merge(aggregated_df, on='tractce', how='left')
#add poverty by tract to aggregated_df
aggregated_gdf = aggregated_gdf.merge(poverty_2023[['tract','pop_est','poverty_rate']], left_on='tractce', right_on='tract', how='left')

# %% [markdown]
# Is there any location inequality in terms of automobile crash rates, pedestrian fatality and injury? What is the relationship between pedestrian fatalities and neighborhood poverty of residence?
#
# Calcurating the variables the pedestrian road traffic fatality rate and the pedestrian road traffic injury rate per 100 road traffic crashes
#
# 1.   The pedestrian road traffic fatality rate: (Number of pedestrian killed / Total population) * 100
# 2.   The pedestrian road traffic injury rate: (Number of pedestrian injured / Total population) * 100
#
# We will use total crashes instead of the population since some areas do not have zipcodes or population data

# %%
#fill na with zero
aggregated_gdf.fillna(0, inplace=True)

# %%
#pedestrian fatality rate
aggregated_gdf['pedestrian_fatality_rate'] = (aggregated_gdf['total_pedestrians_killed'] / aggregated_gdf['total_crashes']).astype(float) * 1000


#pedestrian injury rate
aggregated_gdf['pedestrian_injury_rate'] = (aggregated_gdf['total_pedestrians_injured'] / aggregated_gdf['total_crashes']).astype(float) *100

aggregated_gdf['pedestrian_fatality_rate'].head()

#vurnerable road users fatality rate pedestrians, cyclists, motorists
aggregated_gdf['total_vru_fatality'] = (aggregated_gdf['total_cyclist_killed'] + aggregated_gdf['total_motorist_killed'] + aggregated_gdf['total_pedestrians_killed'])
aggregated_gdf['vru_fatality_rate'] = aggregated_gdf['total_vru_fatality'] / aggregated_gdf['total_crashes']*1000
#vurnerable road user injury rate
aggregated_gdf['total_vru_injury'] = (aggregated_gdf['total_cyclist_injured'] + aggregated_gdf['total_motorist_injured'] + aggregated_gdf['total_pedestrians_injured'])
aggregated_gdf['vru_injury_rate'] = aggregated_gdf['total_vru_injury'] / aggregated_gdf['total_crashes']*1000
#replace nan in poverty rate with 0
aggregated_gdf['poverty_rate'] = aggregated_gdf['poverty_rate'].fillna(0)
#fill total crashes missing with zero
aggregated_gdf['total_crashes'] = aggregated_gdf['total_crashes'].fillna(0)

# %%
ax = aggregated_gdf.plot(column='pedestrian_injury_rate', legend=True, figsize=(15, 10), scheme= 'NaturalBreaks', cmap='YlOrRd')
ax.set_title('Pedestrian Injury Rate per 100 Crashes')
ax.axis('off')
# Out:
# (np.float64(-74.28339245),
#  np.float64(-73.67259655000001),
#  np.float64(40.475146288019964),
#  np.float64(40.93624084342762))

# %%
#visualize the distribution of pedestrian fatality rate side by side with poverty rate
fig, ax = plt.subplots(2, 2, figsize=(15, 15))
aggregated_gdf.plot(column='poverty_rate', legend=True, ax=ax[0,0], figsize=(15, 10), scheme= 'NaturalBreaks', cmap='viridis',
                    legend_kwds={"loc": "upper left"})
aggregated_gdf.plot(column='pedestrian_injury_rate', ax = ax[0,1],legend=True, figsize=(15, 10), scheme= 'NaturalBreaks', cmap='coolwarm',
                    legend_kwds={"loc": "upper left"})
aggregated_gdf.plot(column='pedestrian_fatality_rate', ax = ax[1,0],legend=True, figsize=(15, 10), scheme= 'NaturalBreaks', cmap='coolwarm',
                    legend_kwds={"loc": "upper left"})
aggregated_gdf.plot(column='total_crashes', ax = ax[1,1],legend=True, figsize=(15, 10), scheme= 'NaturalBreaks', cmap='coolwarm',
                    legend_kwds={"loc": "upper left"})
#titles
ax[1,1].set_title('Total Crashes')
ax[1,0].set_title('Pedestrian Fatality per 100 Crashes')
ax[0,0].set_title('Poverty per 100 Population')
ax[0,1].set_title('Pedestrian Injury per 100 Crashes')
#remove axes
ax[0,0].axis('off')
ax[0,1].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')
plt.show()

# %%
#heatmap of pedestrian fatality and injuriy rate by borough with annotation
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(10, 6))
#visualizing pedestrian fatality and injuriy rate normalized by borough with annotation
sns.heatmap(aggregated_gdf.groupby(['borough'])[['pedestrian_fatality_rate','pedestrian_injury_rate']].mean(), annot=True, cmap='YlOrRd')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

#visualizing poverty rate vs number of crashes per zipcode
sns.scatterplot( data = aggregated_gdf,
            ax = ax,
            x = 'poverty_rate',
                 hue ='countyfp',
             y = 'pedestrian_fatality_rate')
#set the title and labels
ax.set_title('Poverty Rate vs Pedestrian Fatality per 100 crashes')
ax.set_xlabel('Poverty Rate')
ax.set_ylabel('Pedestrian Fatality Rate per 100 crashes')
ax.legend(loc="center left",title="County", bbox_to_anchor=(1, 0.5))

plt.show()

# %%
#visualizing poverty rate vs number of crashes per zipcode using lmplot
# lmplot automatically adds a regression line
g = sns.lmplot( data = aggregated_gdf,
            x = 'poverty_rate',
             y = 'pedestrian_injury_rate',
             hue = 'borough',
                col = 'borough',
            ci=None, # No confidence interval
             height=6, # Adjust height as needed
             aspect=1.5) # Adjust aspect ratio as needed

#set the title - Note: lmplot returns a FacetGrid, setting title works slightly differently
# You can get the figure from the FacetGrid object and set the title
g.fig.suptitle('Poverty Rate vs Number of Crashes', y=1.02) # y=1.02 moves the title slightly above the plot


#set the xlabel and ylabel are set automatically by lmplot



plt.show()

# %%
#fit a regression model to quantify the relationship between poverty and pedestrian fatality rate
import statsmodels.api as sm
import statsmodels.formula.api as smf
results = smf.ols('pedestrian_fatality_rate ~ poverty_rate+ borough + poverty_rate*borough', data=aggregated_gdf).fit()
print(results.summary())

# %%
#mean absolute error
from sklearn.metrics import mean_absolute_error,mean_squared_error
y_true = aggregated_gdf['pedestrian_injury_rate'].fillna(0)
y_pred = results.predict(aggregated_gdf)
mae = mean_absolute_error(y_true, y_pred)
mae
mse = mean_squared_error(y_true, y_pred)
mse
print(f'Mean Absolute Error: {mae:.2f} \nRelative Standard Error: {np.sqrt(mse):.2f}')

# %%
# Calculate Pearson Correlation Coefficient
from scipy.stats import pearsonr
COL_POVERTY = 'poverty_rate'
COL_PED_FATALITIES = 'pedestrian_fatality_rate'
#remove nan before proceeding
aggregated_gdf_no_na = aggregated_gdf.dropna(subset=[COL_POVERTY, COL_PED_FATALITIES])
# --- 3. Analyze Relationship by Borough ---
unique_boroughs = aggregated_gdf_no_na['borough'].unique()

print(f"Analyzing relationship for {len(unique_boroughs)} boroughs:\n")

for borough in unique_boroughs:
    print(f"--- Analyzing {borough} ---")
    borough_df = aggregated_gdf_no_na[aggregated_gdf_no_na['borough'] == borough].copy() # .copy() to avoid SettingWithCopyWarning

    # Check if there's enough data for correlation
    if len(borough_df) < 2:
        print(f"Not enough data points for {borough} to calculate correlation (need at least 2).\n")
        continue

    # Scatter Plot
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=COL_POVERTY, y=COL_PED_FATALITIES, data=borough_df)
    plt.title(f'Pedestrian Fatalities vs. Poverty Rate in {borough}')
    plt.xlabel('Poverty Rate (%)')
    plt.ylabel('Pedestrian Fatalities')
    plt.grid(True)
    plt.show()

    # Calculate Pearson Correlation Coefficient
    correlation, p_value = pearsonr(borough_df[COL_POVERTY], borough_df[COL_PED_FATALITIES])

    print(f"Pearson Correlation Coefficient for {borough}: {correlation:.2f}")
    print(f"P-value: {p_value:.3f}")

    # Interpret the correlation
    if abs(correlation) > 0.7:
        strength = "very strong"
    elif abs(correlation) > 0.5:
        strength = "strong"
    elif abs(correlation) > 0.3:
        strength = "moderate"
    else:
        strength = "weak"

    direction = "positive" if correlation > 0 else "negative" if correlation < 0 else "no"

    print(f"Interpretation: There is a {strength} {direction} relationship between pedestrian fatalities and poverty rate in {borough}.")
    if p_value < 0.05:
        print("This relationship is statistically significant (p < 0.05).")
    else:
        print("This relationship is not statistically significant (p >= 0.05), suggesting it might be due to random chance.")
    print("-" * 40 + "\n")

# --- 4. Overall Summary (Conceptual) ---
print("--- Overall Summary of Findings ---")
print("After analyzing each borough, you would look for:")
print("-   **Consistent patterns:** Do all boroughs show a similar type of relationship (e.g., higher poverty, higher fatalities)?")
print("-   **Varying relationships:** Are there boroughs where the relationship is strong, while in others it's weak or non-existent?")
print("-   **Outliers/Anomalies:** Are there any boroughs that deviate significantly from the general trend?")
print("-   **Statistical Significance:** Which relationships are statistically reliable?")
print("\nFurther analysis might involve regression modeling to quantify the impact of poverty while controlling for other factors.")

# %% [markdown]
# 1. **Research Objective**
# The primary objective of this milestone is to investigate location inequality in road safety. Specifically, we examine the relationship between neighborhood socioeconomic status—proxied by the poverty rate—and the severity of pedestrian safety outcomes (injuries and fatalities).
#
# 2. **Data Sources & Integration**
# To perform this analysis, we integrated two primary datasets:NYC OpenData Motor Vehicle Collisions: Real-time police-reported crash data, filtered for geographic coordinates.U.S. Census Bureau ACS 5-Year Estimates (2023): Retrieved via the Census API to obtain total population (B01003_001E) and poverty status (B17001_002E) for every census tract in New York City.TIGER/Line Shapefiles: Spatial boundaries for NYC Census Tracts used to facilitate the geographic join.
#
# 3. **Computational Methodology**
# The analysis was conducted through the following technical pipeline:
# * **Spatial Normalization:** Since collisions are reported as points (latitude/longitude) and poverty is reported by census tract (polygons), we performed a *Spatial Join* (sjoin) using geopandas. This assigned each of the 2M+ crash records to its specific legal census tract boundary.
#
# * **Metric Standardization:** To compare safety across neighborhoods of different sizes and traffic volumes, we calculated standardized rates:
#
# ***Pedestrian Injury Rate*** : $\frac{\text{Total Pedestrians Injured}}{\text{Total Crashes in Tract}} \times 100$Pedestrian
#
# ***Fatality Rate*** : $\frac{\text{Total Pedestrians Killed}}{\text{Total Crashes in Tract}} \times 1,000$
#
# * Statistical Modeling: We utilized **Ordinary Least Squares (OLS) Regression** to quantify the correlation between the poverty_rate (independent variable) and the pedestrian_injury_rate (dependent variable), controlling for borough-level differences.
#
# 4. **Data Cleaning & Integrity**
# * **Missing Data:** Crashes lacking valid coordinate data (approx. 9.42%) were excluded from the spatial join to ensure geographic accuracy.
#
# * **Boundary Refinement:** Water-only tracts were removed using the erase_water function to prevent visual distortion in the choropleth maps.
#
# * **Normalization:** We used "Total Crashes" as the denominator for rates rather than population. This accounts for "commuter risk"—tracts where few people live but high traffic volume creates significant risk for pedestrians.

# %% [markdown]
# ## **Summary of Findings**
# The analysis identifies a statistically significant correlation ($p < 0.05$) between neighborhood poverty rates and pedestrian fatality rates. This suggests that socioeconomic factors are a critical determinant of road safety, and that public health interventions should be prioritized in economically disadvantaged neighborhoods.
#
# **Model Performance & Limitations**
#
# While the relationship is significant, the low $R^2$ indicates that poverty alone explains only a small fraction of the variance in safety outcomes. The model’s predictive power is likely constrained by several key factors:
# * **Omitted Variable Bias:** Future iterations should incorporate critical covariates such as **traffic volume (VMT)**, **population density**, and **infrastructure quality** (e.g., presence of protected bike lanes or high-visibility crosswalks).
#
# * **Assumption Violations: **
#
# The model is limited by Heteroscedasticity and Spatial Autocorrelation, which are common in urban spatial data where risk factors cluster geographically.
#
# * **Distributional Mismatch: **
#
# The prevalence of "zero-event" tracts (tracts with no fatalities) violates the OLS assumption of normality.Future Research DirectionsTo improve the robustness of these findings, I recommend transitioning from a linear OLS framework to a Poisson or Negative Binomial regression model, which is specifically designed to handle "count data" and zero-inflation. Additionally, incorporating land-use patterns—distinguishing between commercial and residential corridors—would provide a more nuanced understanding of where the highest risks reside.

# %% [markdown]
# ##<font color='green'>**Milestone #6 - Potential Interventions**</font>
#
# GOAL: The main goal of this milestone is to think about the recommendations and possible interventions that we make offer based on our analysis. You will be given an open-ended question that you may research however you like, as long as it's approachable and appropriate. We've included an example for research inspiration below!

# %% [markdown]
# **Step 1:** Analyze the data to research the following question:
#
# What are potential interventions (e.g., intersection redesign, traffic signal control optimization including adding leading pedestrian intervals, speed limit adjustment) that you would suggest to mitigate collisions between cars and vulnerable road users (VRU)?

# %% [markdown]
# **Example**: Here is an example answer to inspire you, leveraging an outside resource like Google Maps.
#
# It is unexpected that Manhattan is not the borough with the highest number of crashes. The top collision region in year 2018 is zipcode 11207 in Brooklyn. Within this zipcode area, Broadway and Graham Avenue have the highest density of crashes; however, neither of those two streets has bike lanes.
#
# By viewing the Google Map road configuration, the commonality between these two steets is the lack of, or poor construction of, bike lanes. The street conditions remain to be improved; some bike lanes are either not marked clearly or blocked by trucks or parking vehicles. Due to these facts, **we suggest adding new bike lanes to some significant streets which have the first or second highest cycling crash rate in this region.**

# %% [markdown]
# **Questions**:
#
#
#
# *   What is the relationship between street orientation in census tract/or borough to vru road user?
# *   What is the bike lane densisty in each cencus tract
# *   Is there a relationship between bikelane density and vru injury rate?
#
#
# ---

# %%
# Begin here! Feel free to be creative.


boroughs_boundaries = gpd.read_file(DATA_DIRECTORY/"nyc_buroughs_boundaries.gpkg")
#aggregated_gdf = gpd.read_file(DATA_DIRECTORY/"nyc_aggregated_crashes_by_zipcode.gpkg")/ /content/drive/MyDrive/TDSP/nyc_buroughs_boundaries.gpkg

# %% [markdown]
# **TO DO:** Write a short explanation of your methods above. Did your research provide you with additional insights? Do you have any new recommendations for DOT FHWA based on your findings?
# > *
# Based on the statistical significance of poverty as a risk factor and the disproportionate impact of certain vehicle types, the following interventions are recommended for the NYC Department of Transportation:
#
# 1. **Equity-Based Vision Zero Priority Zones**
#
# * **The Issue:** Our OLS model confirmed that higher poverty rates correlate with increased pedestrian fatalities.
#
# * **Recommendation:** Establish "Safety Equity Zones" in census tracts within the highest poverty quartile. These zones should receive accelerated funding for "hard" infrastructure improvements, such as Lead Pedestrian Intervals (LPIs) and Daylighting (removing parking spaces near crosswalks to improve visibility), regardless of reported crash volume. This shifts the strategy from reactive (fixing areas after crashes happen) to proactive (fixing areas based on systemic risk).
#
# **2. SUV-Specific Safety Regulations & Urban Design**
#
# **Specific Infrastructure Adjustments **in dense pedestrian corridors. This includes tightening curb radii to force larger vehicles to turn more slowly and advocating for federal "Pedestrian-Friendly" front-end standards. Locally, NYC could implement a "Safety Surcharge" on heavy SUVs registered within the city, with proceeds directed toward the Vision Zero infrastructure fund.
#
#
# **3. "Automated Enforcement" in High-Risk Corridors**
# **The Issue:** The drop in crashes during the 2020 pandemic was offset by increased speeds on open roads, as noted in the Time Series analysis.
#
# **Recommendation: ** Expand the use of Automated Speed and Red-Light Cameras, specifically along arterial roads that pass through multiple high-poverty census tracts (addressing the Spatial Autocorrelation noted in our model). Data-driven placement ensures enforcement is targeted where the risk of fatality is highest, rather than where it is most convenient to patrol.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='green'>  **Milestone #7 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# You may create your visualization(s) in this Colab Notebook, or in Excel, Tableau, PowerBI, etc. Choose whichever medium you are most comfortable with! Be creative!
#
# For participants who are comfortable with advanced data science techniques, we welcome you to leverage additional datasets, if desired. We highly recommend using pre-cleaned datasets from open data sources, like Kaggle.com.
#
# If you have any questions or get stuck, please email nsdc@nebigdatahub.org with your queries. We're here to help!

# %% [markdown]
# **Step 1:** Review the dataset(s) that you will be using. As you explore, [consider the research question you want to answer](https://libraries.indiana.edu/sites/default/files/Develop_a_Research_Question.pdf)! Additionally, think about [who you are telling you data's story to](https://hbr.org/2013/04/how-to-tell-a-story-with-data). Your final audience may contain a group of transportation professionals, data scientists, peers, and the general public.Think about how would you frame your analysis differently for each of these groups.

# %% [markdown]
# **TO DO:** List one or more research questions here that you are considering.
#
# > *

# %% [markdown]
# What is the relationship between bike lane desnsity to the vru injury rate? is there a difference based on land use (commercial vs residential areas)

# %% [markdown]
# **Step 2:** Think about what type of analysis you'd like to complete. Are you interested in looking at time series forecasting? Do you have additional maps in mind that you'd like to create? Is there a certain zip code or region you'd like to dive deeper into?
#
# If you happen to be stuck, here are some examples that you can use or can guide you in choosing your research question!
#
# **Examples:**
# - Which zip code sees the highest amount of crashes and what recommendations can you offer to help that community?
# - Do more crashes occur in underrepresented communities? Why or why not?
# - Are older vehicles or newer vehicles involved in more crashes?
# - Do the geometric features of an intersection (90 degree intersection vs skewed intersection) affect the number of crashes that occur?
# - How does seat belt use affect the severity of a crash?
# - How has the increase of mobile map use affected the frequency or severity of crashes?
#
# Be creative and think outside the box!

# %% [markdown]
# **Step 3:** Now that you've decided on your transportation research question, [explore the various types of visualizations you can create to support your research](https://datavizcatalogue.com/). You may create visualizations in this Google Colab notebook, Excel, R, SQL, PowerBI, Tableau, etc. Choose a program you are comfortable with!
#
# You may also choose to build a model or leverage a different data science technique based on your experience level.

# %% [markdown]
# **Step 4:** Consider the **accessibility** of the graphs, charts, maps, or models you are interested in building. Use the tools below to learn more!
# * How does your visualization appear to people with disabilities [who may not be able to distinguish between muted colors or see your chart at all?](https://chartability.fizz.studio/)
# *[Color Contrast Checker](https://policyviz.com/2022/11/01/color-contrast-checker-in-excel/)
# *[SAS Graphics Accelerator](https://support.sas.com/software/products/graphics-accelerator/index.html)
# *[TwoTone Data Sonification Tool](https://twotone.io/about/)
# *[Making Visual Studio Accessible](https://code.visualstudio.com/docs/editor/accessibility)

# %% [markdown]
# To make visualizations more inclusive for people with color blindness, you can choose a color palette that is colorblind-friendly. `Seaborn`, a Python visualization library, provides several palettes that are designed to be perceptible by those with color vision deficiencies. Seaborn's `cubehelix` palette is a good choice, as it was designed specifically with color blindness in mind.

# %% [markdown]
# **Step 5:** Begin your research! Give yourself plenty of time to build your visualization or model. If you have any questions along the way, please email er3101@columbia.edu or write a message in the #[tdsp-community Slack Channel](https://join.slack.com/t/nsdcorps/shared_invite/zt-1h64t1e2p-La0AgU_HhymWUEGFQEcb3w).

# %% [markdown]
# **TO DO:** List the research question(s) you've chosen and why! Maybe you chose this question because it can help a community of interest or because it is similar to research you've completed in a class setting. Share your thoughts below.
#
# > *

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %%
#TO DO: Begin creating here!

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='green'>**Milestone #8 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🛺<font color='green'> **Thank you for completing the project!**</font> 🛺
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
